# %%
import pandas as pd

# %%
dataset=pd.read_csv("PT_INR_Prothrombin _Introduction _Test _Result_Dataset .csv")

# %%
dataset
# Out:
#       Patient ID  Age  Gender   PT Value  INR Value   Health Condition  \
# 0              1   69    Male  18.355144   2.765927             Normal
# 1              2   32    Male  10.894440   2.480643             Normal
# 2              3   89    Male  15.985299   2.662863             Normal
# 3              4   78    Male  18.171537   2.927404             Normal
# 4              5   38  Female  13.652989   3.195382  Bleeding Disorder
# ...          ...  ...     ...        ...        ...                ...
# 6995        6996   69  Female  16.801529   2.319676             Normal
# 6996        6997   23    Male  23.064043   2.153335             Normal
# 6997        6998   86  Female  16.917810   2.861205             Normal
# 6998        6999   91    Male  16.872807   2.359891             Normal
# 6999        7000   26    Male  18.434645   2.780392  Bleeding Disorder
#
#       Treatment Type Risk Level
# 0          Vitamin K        Low
# 1     Anticoagulants        Low
# 2          Vitamin K        Low
# 3     Anticoagulants        Low
# 4          Vitamin K       High
# ...              ...        ...
# 6995             NaN        Low
# 6996             NaN        Low
# 6997  Anticoagulants        Low
# 6998  Anticoagulants        Low
# 6999  Anticoagulants   Moderate
#
# [7000 rows x 8 columns]

# %%
print(dataset.columns)
# Out:
# Index(['Patient ID', 'Age', 'Gender', 'PT Value', 'INR Value',
#        'Health Condition', 'Treatment Type', 'Risk Level'],
#       dtype='object')

# %%
dataset = dataset.drop(columns=['Patient ID','Health Condition','Treatment Type'])

# %%
# Perform one-hot encoding with drop_first=True
dataset= pd.get_dummies(dataset, drop_first=True)

# %%
dataset
# Out:
#       Age   PT Value  INR Value  Gender_Male  Risk Level_Low  \
# 0      69  18.355144   2.765927         True            True
# 1      32  10.894440   2.480643         True            True
# 2      89  15.985299   2.662863         True            True
# 3      78  18.171537   2.927404         True            True
# 4      38  13.652989   3.195382        False           False
# ...   ...        ...        ...          ...             ...
# 6995   69  16.801529   2.319676        False            True
# 6996   23  23.064043   2.153335         True            True
# 6997   86  16.917810   2.861205        False            True
# 6998   91  16.872807   2.359891         True            True
# 6999   26  18.434645   2.780392         True           False
#
#       Risk Level_Moderate
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 6995                False
# 6996                False
# 6997                False
# 6998                False
# 6999                 True
#
# [7000 rows x 6 columns]

# %%
# Convert specific columns from True/False to 0/1
columns = ['Gender_Male', 'Risk Level_Low', 'Risk Level_Moderate']
dataset[columns] = dataset[columns].astype(int)

# %%
dataset
# Out:
#       Age   PT Value  INR Value  Gender_Male  Risk Level_Low  \
# 0      69  18.355144   2.765927            1               1
# 1      32  10.894440   2.480643            1               1
# 2      89  15.985299   2.662863            1               1
# 3      78  18.171537   2.927404            1               1
# 4      38  13.652989   3.195382            0               0
# ...   ...        ...        ...          ...             ...
# 6995   69  16.801529   2.319676            0               1
# 6996   23  23.064043   2.153335            1               1
# 6997   86  16.917810   2.861205            0               1
# 6998   91  16.872807   2.359891            1               1
# 6999   26  18.434645   2.780392            1               0
#
#       Risk Level_Moderate
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 6995                    0
# 6996                    0
# 6997                    0
# 6998                    0
# 6999                    1
#
# [7000 rows x 6 columns]

# %%
#to separate columns from dataset
dataset.columns
# Out:
# Index(['Age', 'PT Value', 'INR Value', 'Gender_Male', 'Risk Level_Low',
#        'Risk Level_Moderate'],
#       dtype='object')

# %%
independent = dataset[['Age', 'PT Value', 'INR Value', 'Gender_Male']]
independent
# Out:
#       Age   PT Value  INR Value  Gender_Male
# 0      69  18.355144   2.765927            1
# 1      32  10.894440   2.480643            1
# 2      89  15.985299   2.662863            1
# 3      78  18.171537   2.927404            1
# 4      38  13.652989   3.195382            0
# ...   ...        ...        ...          ...
# 6995   69  16.801529   2.319676            0
# 6996   23  23.064043   2.153335            1
# 6997   86  16.917810   2.861205            0
# 6998   91  16.872807   2.359891            1
# 6999   26  18.434645   2.780392            1
#
# [7000 rows x 4 columns]

# %%
dependent = dataset[['Risk Level_Low']]
dependent
# Out:
#       Risk Level_Low
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  0
# ...              ...
# 6995               1
# 6996               1
# 6997               1
# 6998               1
# 6999               0
#
# [7000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#sklearn is library function,linear_model is folder to find linear simple regersion(weight,slop(coef)),(bias as a intercept).,regerssor as model variables,linear regerctionis class of all function non parameterized assing
#fit method is model
from sklearn.linear_model import LinearRegression 
regerssor=LinearRegression()
regerssor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight=regerssor.coef_
weight
# Out:
# array([[-0.00054681,  0.00031609, -0.01202596,  0.01501513]])

# %%
bios=regerssor.intercept_
bios
# Out:
# array([0.45070548])

# %%
y_pred=regerssor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# -0.004216514950490247

# %%
import pickle
filename="PT_INR_Prothrombin.csv"

# %%
pickle.dump(regerssor,open(filename,"wb"))

# %%
loaded_model = pickle.load(open("PT_INR_Prothrombin.csv", "rb"))
result = loaded_model.predict([[69, 18.355144, 2.765927, 1]])
print("Prediction for input [69, 18.355144, 2.765927, 1]:", result)
# Out:
# Prediction for input [69, 18.355144, 2.765927, 1]: [[0.40052974]]
# C:\Users\ragus\anaconda3\envs\AgriYieldAI\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted Risk Level: Not Low",result)
# Out:
# Predicted Risk Level: Not Low [[0.40052974]]
